# %%
from function_litref import *

# %%
articles = get_files_in_folder("/home/jules/Documents/phd/obsidian_vault/Article_note/")

# %%
title = 'Comprehensive evaluation of deconvolution methods for human brain gene expression.md'


test = search_by_title(title=title)
test
# Out:
# {'total': 2,
#  'offset': 0,
#  'data': [{'paperId': '722c73101a36d6307a42471ed6ac05458ec87029',
#    'title': 'Comprehensive evaluation of deconvolution methods for human brain gene expression'},
#   {'paperId': '72fdf28c1adbab503365a698327d595fa96e83c4',
#    'title': 'Comprehensive evaluation of deconvolution methods for human brain gene expression'}]}

# %%
infos = get_paper_info("ab82bdfb1710a470d4358afa312d7c9da531632b")
infos
# Out:
# {'paperId': 'ab82bdfb1710a470d4358afa312d7c9da531632b',
#  'title': 'Guidance for RNA-seq co-expression network construction and analysis: safety in numbers',
#  'references': [{'paperId': '5e814fc3615ed7e9a55b33510998e91ceca7672a',
#    'title': 'Measuring the wisdom of the crowds in network-based gene function inference'},
#   {'paperId': '0446839238dc22746e99eb746ce11bc7e18f33b1',
#    'title': 'A comprehensive assessment of RNA-seq accuracy, reproducibility and information content by the Sequencing Quality Control consortium'},
#   {'paperId': 'ac5e0caf4ff09abff6e4a51c1e1388dae7f7eaf8',
#    'title': 'Detecting and correcting systematic variation in large-scale RNA sequencing data'},
#   {'paperId': '17868f976dd014be13acaf1ceff94c802abf14a0',
#    'title': 'RNA-seq differential expression studies: more sequence or more replication?'},
#   {'paperId': '0fa6c95598393f7fa0c9969d6c3856b635c25470',
# ...

# %%
infos["references"]
# Out:
# [{'paperId': '5e814fc3615ed7e9a55b33510998e91ceca7672a',
#   'title': 'Measuring the wisdom of the crowds in network-based gene function inference'},
#  {'paperId': '0446839238dc22746e99eb746ce11bc7e18f33b1',
#   'title': 'A comprehensive assessment of RNA-seq accuracy, reproducibility and information content by the Sequencing Quality Control consortium'},
#  {'paperId': 'ac5e0caf4ff09abff6e4a51c1e1388dae7f7eaf8',
#   'title': 'Detecting and correcting systematic variation in large-scale RNA sequencing data'},
#  {'paperId': '17868f976dd014be13acaf1ceff94c802abf14a0',
#   'title': 'RNA-seq differential expression studies: more sequence or more replication?'},
#  {'paperId': '0fa6c95598393f7fa0c9969d6c3856b635c25470',
#   'title': 'Integrative Functional Genomic Analyses Implicate Specific Molecular Pathways and Circuits in Autism'},
#  {'paperId': 'd6720c598d391cc4f2cf6d6ac0b1a779070e6804',
# ...

# %%
get_reference_titles(title)
# Out:
# ['A benchmark for RNA-seq deconvolution analysis under dynamic testing environments',
#  'Genome-wide association study implicates novel loci and reveals candidate effector genes for longitudinal pediatric bone accrual',
#  'Benchmarking of cell type deconvolution pipelines for transcriptomics data',
#  'Single-nucleus transcriptomics of the prefrontal cortex in major depressive disorder implicates oligodendrocyte precursor cells and excitatory neurons',
#  'SINGLE',
#  'Correction: Differential transcriptional response following glucocorticoid activation in cultured blood immune cells: a novel approach to PTSD biomarker development',
#  'Single-cell reconstruction of the adult human heart during heart failure and recovery reveals the cellular landscape underlying cardiac function',
#  'deconvSeq: deconvolution of cell mixture distribution in sequencing data',
#  'The Role of Scale in the Estimation of Cell-type Proportions',
# ...

# %%
vault_path = "/home/jules/Documents/phd/obsidian_vault/Article_note/"
title = "Comprehensive evaluation of deconvolution methods for human brain gene expression.md"


add_references(title,vault_path)
